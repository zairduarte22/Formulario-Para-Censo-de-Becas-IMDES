# %% [markdown]
# ### Realizar las importaciones necesarias para la limpieza

# %%
import pandas as pd
import numpy as np
import datetime

# %% [markdown]
# ### Leer y mostrar los primeros registros del csv para estudiar su estructura

# %%
data = pd.read_csv('mock_becas.csv')
data.head()
# Out:
#         fecha estado          municipio       parroquia             sector  \
# 0  2026-08-16  Zulia  ROSARIO DE PERIJA  DONALDO GARCÍA  Villa del Rosario
# 1  2026-08-10  Zulia  ROSARIO DE PERIJA  DONALDO GARCÍA         San Miguel
# 2  2026-08-18  Zulia  ROSARIO DE PERIJA      EL ROSARIO             Corito
# 3  2026-08-22  Zulia  ROSARIO DE PERIJA      EL ROSARIO          El Carmen
# 4  2026-08-08  Zulia  ROSARIO DE PERIJA      EL ROSARIO         San Miguel
#
#                  nombres_completos    cedula genero fecha_nacimiento  \
# 0  Valentina Diego Romero Martinez  27678312      F       2006-09-16
# 1     Marta Fernando Mendoza Gomez  31210094      M       2007-10-25
# 2          Ana Camila Lopez Romero  30301647      M       2007-10-05
# 3        Gabriel Lucia Diaz Flores  31081450      F       2010-02-17
# 4     Diego Elena Gonzalez Ramirez  26145713      M       2007-11-27
#
#                               direccion  ... fuente_ingreso trabaja  \
# 0  Calle 11, Villa del Rosario, casa 10  ...         FORMAL      NO
# 1          Calle 1, San Miguel, casa 22  ...         FORMAL      NO
# 2              Calle 2, Corito, casa 11  ...        NINGUNO      NO
# 3          Calle 13, El Carmen, casa 31  ...       INFORMAL      NO
# 4          Calle 4, San Miguel, casa 12  ...       INFORMAL      NO
#
#                           dificultades                                apoyos  \
# 0                               utiles        material_escolar, beca, empleo
# 1  transporte, hospedaje, alimentacion  alimentacion_apoyo, material_escolar
# 2  alimentacion, hospedaje, tecnologia   alimentacion_apoyo, ayuda_economica
# 3      utiles, matricula, alimentacion  transporte_apoyo, alimentacion_apoyo
# 4                            hospedaje                      transporte_apoyo
#
#                            banco tipo_cuenta        numero_cuenta  \
# 0               Banco del Tesoro      Ahorro  1630000674469291241
# 1  Banco Occidental de Descuento   Corriente  1160000614363134552
# 2                Banco Mercantil   Corriente  1050000235919541989
# 3                BBVA Provincial   Corriente  1080000242434175978
# 4               Banco del Tesoro   Corriente  1630000217247997637
#
#    servicio_comunitario              horarios ubicacion_universidad
# 0                    SI       Martes y jueves             Maracaibo
# 1                    SI     Lunes y miercoles              La Villa
# 2                    SI  Sabados en la manana               foraneo
# 3                    NO                   NaN              La Villa
# 4                    NO                   NaN              La Villa
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Realizar los reemplazos necesarios para crear graficos eficientemente

# %%
data['ubicacion_universidad'] = data['ubicacion_universidad'].replace({'La Villa': 'La Villa Del Rosario', 'foraneo':'Maracaibo'})
data['servicio_comunitario'] = data['servicio_comunitario'].replace({'SI':'Acepto', 'NO':'No acepto'})
data['trabaja'] = data['trabaja'].replace({'SI':'Trabaja', 'NO':'No Trabaja'})
data.head()
# Out:
#         fecha estado          municipio       parroquia             sector  \
# 0  2026-08-16  Zulia  ROSARIO DE PERIJA  DONALDO GARCÍA  Villa del Rosario
# 1  2026-08-10  Zulia  ROSARIO DE PERIJA  DONALDO GARCÍA         San Miguel
# 2  2026-08-18  Zulia  ROSARIO DE PERIJA      EL ROSARIO             Corito
# 3  2026-08-22  Zulia  ROSARIO DE PERIJA      EL ROSARIO          El Carmen
# 4  2026-08-08  Zulia  ROSARIO DE PERIJA      EL ROSARIO         San Miguel
#
#                  nombres_completos    cedula genero fecha_nacimiento  \
# 0  Valentina Diego Romero Martinez  27678312      F       2006-09-16
# 1     Marta Fernando Mendoza Gomez  31210094      M       2007-10-25
# 2          Ana Camila Lopez Romero  30301647      M       2007-10-05
# 3        Gabriel Lucia Diaz Flores  31081450      F       2010-02-17
# 4     Diego Elena Gonzalez Ramirez  26145713      M       2007-11-27
#
#                               direccion  ... fuente_ingreso     trabaja  \
# 0  Calle 11, Villa del Rosario, casa 10  ...         FORMAL  No Trabaja
# 1          Calle 1, San Miguel, casa 22  ...         FORMAL  No Trabaja
# 2              Calle 2, Corito, casa 11  ...        NINGUNO  No Trabaja
# 3          Calle 13, El Carmen, casa 31  ...       INFORMAL  No Trabaja
# 4          Calle 4, San Miguel, casa 12  ...       INFORMAL  No Trabaja
#
#                           dificultades                                apoyos  \
# 0                               utiles        material_escolar, beca, empleo
# 1  transporte, hospedaje, alimentacion  alimentacion_apoyo, material_escolar
# 2  alimentacion, hospedaje, tecnologia   alimentacion_apoyo, ayuda_economica
# 3      utiles, matricula, alimentacion  transporte_apoyo, alimentacion_apoyo
# 4                            hospedaje                      transporte_apoyo
#
#                            banco tipo_cuenta        numero_cuenta  \
# 0               Banco del Tesoro      Ahorro  1630000674469291241
# 1  Banco Occidental de Descuento   Corriente  1160000614363134552
# 2                Banco Mercantil   Corriente  1050000235919541989
# 3                BBVA Provincial   Corriente  1080000242434175978
# 4               Banco del Tesoro   Corriente  1630000217247997637
#
#    servicio_comunitario              horarios ubicacion_universidad
# 0                Acepto       Martes y jueves             Maracaibo
# 1                Acepto     Lunes y miercoles  La Villa Del Rosario
# 2                Acepto  Sabados en la manana             Maracaibo
# 3             No acepto                   NaN  La Villa Del Rosario
# 4             No acepto                   NaN  La Villa Del Rosario
#
# [5 rows x 28 columns]

# %% [markdown]
# ### Calcular la fecha de nacimiento para poder categorizar a los estudiantes en menores o mayores de edad

# %%
data['fecha_nacimiento'] = pd.to_datetime(data['fecha_nacimiento'], errors='coerce')
data['edad'] = (datetime.datetime.now() - data['fecha_nacimiento']).dt.days // 365
# Creación de la columna "edad_categorica" basada en la edad (Binning)
# limite = 18
"""data["categoria_edad"] = np.where(
    data["edad"] < limite,
    "Menor de 18 años",
    "Mayor o igual a 18 años"
)"""
# Creación de la columna "edad_categorica" usando pd.cut() para categorizar la edad en "Menor de edad" y "Mayor de edad"
bins_edad = [-np.inf, 17, np.inf]
labels_edad = ['Menor de edad', 'Mayor de edad']
data['edad_categorica'] = pd.cut(data['edad'], bins=bins_edad, labels=labels_edad, include_lowest=True)
data.head()
# Out:
#         fecha estado          municipio       parroquia             sector  \
# 0  2026-08-16  Zulia  ROSARIO DE PERIJA  DONALDO GARCÍA  Villa del Rosario
# 1  2026-08-10  Zulia  ROSARIO DE PERIJA  DONALDO GARCÍA         San Miguel
# 2  2026-08-18  Zulia  ROSARIO DE PERIJA      EL ROSARIO             Corito
# 3  2026-08-22  Zulia  ROSARIO DE PERIJA      EL ROSARIO          El Carmen
# 4  2026-08-08  Zulia  ROSARIO DE PERIJA      EL ROSARIO         San Miguel
#
#                  nombres_completos    cedula genero fecha_nacimiento  \
# 0  Valentina Diego Romero Martinez  27678312      F       2006-09-16
# 1     Marta Fernando Mendoza Gomez  31210094      M       2007-10-25
# 2          Ana Camila Lopez Romero  30301647      M       2007-10-05
# 3        Gabriel Lucia Diaz Flores  31081450      F       2010-02-17
# 4     Diego Elena Gonzalez Ramirez  26145713      M       2007-11-27
#
#                               direccion  ...  \
# 0  Calle 11, Villa del Rosario, casa 10  ...
# 1          Calle 1, San Miguel, casa 22  ...
# 2              Calle 2, Corito, casa 11  ...
# 3          Calle 13, El Carmen, casa 31  ...
# 4          Calle 4, San Miguel, casa 12  ...
#
#                           dificultades                                apoyos  \
# 0                               utiles        material_escolar, beca, empleo
# 1  transporte, hospedaje, alimentacion  alimentacion_apoyo, material_escolar
# 2  alimentacion, hospedaje, tecnologia   alimentacion_apoyo, ayuda_economica
# 3      utiles, matricula, alimentacion  transporte_apoyo, alimentacion_apoyo
# 4                            hospedaje                      transporte_apoyo
#
#                            banco tipo_cuenta        numero_cuenta  \
# 0               Banco del Tesoro      Ahorro  1630000674469291241
# 1  Banco Occidental de Descuento   Corriente  1160000614363134552
# 2                Banco Mercantil   Corriente  1050000235919541989
# 3                BBVA Provincial   Corriente  1080000242434175978
# 4               Banco del Tesoro   Corriente  1630000217247997637
#
#   servicio_comunitario              horarios  ubicacion_universidad edad  \
# 0               Acepto       Martes y jueves              Maracaibo   19
# 1               Acepto     Lunes y miercoles   La Villa Del Rosario   18
# 2               Acepto  Sabados en la manana              Maracaibo   18
# 3            No acepto                   NaN   La Villa Del Rosario   16
# 4            No acepto                   NaN   La Villa Del Rosario   18
#
#   edad_categorica
# 0   Mayor de edad
# 1   Mayor de edad
# 2   Mayor de edad
# 3   Menor de edad
# 4   Mayor de edad
#
# [5 rows x 30 columns]

# %% [markdown]
# ### Finalmente, se exporta el csv con las columnas necesarias para construir el dashboard con las metricas solicitadas.

# %%
data.to_csv('mock_becas_limpio.csv', index=False)
